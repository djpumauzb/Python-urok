# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = 'sample_data/california_housing_train.csv'
df = pd.read_csv(file)

# %% [markdown]
# # Задача №63.
# 1. Изобразите отношение `households` к `population` с
# помощью точечного графика
# 2. Визуализировать `longitude` по отношения к
# `median_house_value`, используя **линейный график**
# 3. Представить гистограмму по `housing_median_age`
# 4. Изобразить гистограмму по `median_house_value` с
# оттенком `housing_median_age`

# %%
sns.scatterplot(df, x='households', y='population')
# plt.show() # optional

# %%
sns.relplot(data=df, x='longitude', y='median_house_value', kind='line')
# plt.show()

# %%
sns.histplot(data=df, x='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(data=df, x='median_house_value', hue='housing_median_age')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# # Задача №65
# Написать EDA для датасета про пингвинов
# Необходимо:
# 1. Использовать 2-3 точечных графика
# 2. Применить доп измерение в точечных графиках, используя аргументы `hue`, `size`, `stile`
# 3. Использовать `PairGrid` с типом графика на ваш выбор
# 4. Изобразить `Heatmap`
# 5. Использовать 2-3 гистограммы
#
# Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом:
# `penguins = sns.load_dataset("penguins")`
# `penguins.head()`

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.scatterplot(penguins)
# Out:
# <Axes: >

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen        39.10000           18.7              181.0
# 1  Adelie  Torgersen        39.50000           17.4              186.0
# 2  Adelie  Torgersen        40.30000           18.0              195.0
# 3  Adelie  Torgersen        43.92193            NaN                NaN
# 4  Adelie  Torgersen        36.70000           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.bill_length_mm = penguins.bill_length_mm.fillna(penguins.bill_length_mm.mean())
penguins.bill_depth_mm = penguins.bill_depth_mm.fillna(penguins.bill_depth_mm.mean())
penguins.flipper_length_mm = penguins.flipper_length_mm.fillna(penguins.flipper_length_mm.mean())
penguins.body_mass_g = penguins.body_mass_g.fillna(penguins.body_mass_g.mean())
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen        39.10000       18.70000         181.000000
# 1  Adelie  Torgersen        39.50000       17.40000         186.000000
# 2  Adelie  Torgersen        40.30000       18.00000         195.000000
# 3  Adelie  Torgersen        43.92193       17.15117         200.915205
# 4  Adelie  Torgersen        36.70000       19.30000         193.000000
#
#    body_mass_g     sex
# 0  3750.000000    Male
# 1  3800.000000  Female
# 2  3250.000000  Female
# 3  4201.754386     NaN
# 4  3450.000000  Female

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='flipper_length_mm', y='body_mass_g')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins, x='flipper_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='species', y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins, x='body_mass_g', y='species', hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %%
sns.scatterplot(data=penguins, x='body_mass_g', y='flipper_length_mm', hue='sex', size='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data=penguins, x='body_mass_g', y='flipper_length_mm', hue='species', size='island', style='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
cols = ['bill_length_mm','bill_depth_mm',	'flipper_length_mm',	'body_mass_g']
g = sns.PairGrid(penguins[cols])
g.map(sns.scatterplot)

# %%
sns.PairGrid(penguins, hue='species').map(sns.scatterplot)

# %%
sns.PairGrid(penguins, hue='species').map(sns.scatterplot,).add_legend()

# %%
sns.histplot(data=penguins, x='bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', hue='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', hue='sex', multiple='stack')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', hue='sex', multiple='dodge')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', hue='sex', multiple='layer')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', hue='sex', multiple='fill')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %% [markdown]
# # Задача №67
# 1. Создать новый столбец в таблице с пингвинами, который будет отвечать
# за показатель длины клюва пингвина.
# * high - длинный(от 42)
# * middle - средний(от 35 до 42)
# * low - маленький(до 35)

# %%
penguins.loc[penguins.bill_length_mm >= 42, 'bill_group'] = 'high'
penguins.loc[(penguins.bill_length_mm >= 35) & (penguins.bill_length_mm <= 42), 'bill_group'] = 'middle'
penguins.loc[penguins.bill_length_mm <= 35, 'bill_group'] = 'low'
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen        39.10000       18.70000         181.000000
# 1  Adelie  Torgersen        39.50000       17.40000         186.000000
# 2  Adelie  Torgersen        40.30000       18.00000         195.000000
# 3  Adelie  Torgersen        43.92193       17.15117         200.915205
# 4  Adelie  Torgersen        36.70000       19.30000         193.000000
#
#    body_mass_g     sex bill_group
# 0  3750.000000    Male     middle
# 1  3800.000000  Female     middle
# 2  3250.000000  Female     middle
# 3  4201.754386     NaN       high
# 4  3450.000000  Female     middle

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='bill_group')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='bill_group', multiple='stack')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>
